# %%
from utility import *

from collections import Counter
from scipy.stats import ks_2samp

import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Dataset Loading

# %% [markdown]
# The data sets needed for the loaders can be found at snap.stanford.edu/decagon. The side effect information was curated from the TWOSIDES, OFFSIDES, and Sider databases.

# %%
combo2stitch, combo2se, se2name = load_combo_se()
net, node2idx = load_ppi()
stitch2se, se2name_mono = load_mono_se()
stitch2proteins = load_targets(fname='/home/mamonteiro/datasets/bio-decagon-targets-all.csv')
se2class, se2name_class = load_categories()
se2name.update(se2name_mono)
se2name.update(se2name_class)

# %%
se2name
# Out:
# {'C0151714': 'hypermagnesemia',
#  'C0035344': 'retinopathy of prematurity',
#  'C0004144': 'atelectasis',
#  'C0002063': 'alkalosis',
#  'C0004604': 'Back Ache',
#  'C0034063': 'lung edema',
#  'C0085631': 'agitated',
#  'C0013384': 'abnormal movements',
#  'C0001122': 'Acidosis',
#  'C0034150': 'peliosis',
#  'C0038000': 'rupture of spleen',
#  'C0003578': 'Apnea',
#  'C0013182': 'Drug hypersensitivity',
#  'C0016204': 'flatulence',
#  'C0242429': 'pain in throat',
#  'C0020517': 'allergies',
#  'C0040034': 'thrombocytopenia',
#  'C0428977': 'bradycardia',
#  'C0235896': 'lung infiltration',
#  'C0019080': 'Bleeding',
#  'C0158986': 'hypoglycaemia neonatal',
#  'C0236124': 'Gastrointestinal Obstruction',
#  'C0020456': 'hyperglycaemia',
#  'C0031154': 'peritonitis',
#  'C0020615': 'hypoglycaemia',
#  'C0000731': 'abdominal distension',
#  'C0018790': 'asystole',
#  'C0007785': 'cerebral infarct',
#  'C0242184': 'hypoxia',
#  'C0013404': 'Difficulty breathing',
#  'C0020672': 'decreased body temperature',
#  'C0030446': 'adynamic ileus',
#  'C0243026': 'sepsis',
#  'C0151723': 'Hypomagnesaemia',
#  'C0035220': 'neonatal respiratory distress syndrome',
#  'C0035222': 'Acute Respiratory Distress Syndrome',
#  'C0023798': 'lipoma',
#  'C0030790': 'pelvic infection',
#  'C0003611': 'appendectomy',
#  'C0016199': 'flank pain',
#  'C0032326': 'pneumothorax',
#  'C0003615': 'appendicitis',
#  'C0038379': 'Strabismus',
#  'C0020598': 'Blood calcium decreased',
#  'C1145670': 'respiratory failure',
#  'C0020542': 'pulmonary hypertension',
#  'C0020440': 'Hypercapnia',
#  'C0021845': 'intestinal perforation',
#  'C0023518': 'leucocytosis',
#  'C0024115': 'Disorder Lung',
#  'C0020040': 'hot flash',
#  'C0020649': 'arterial pressure NOS decreased',
#  'C0220981': 'metabolic acidosis',
#  'C0010692': 'Bladder inflammation',
#  'C0003962': 'ascites',
#  'C0013274': 'patent ductus arteriosis',
#  'C0039239': 'sinus tachycardia',
#  'C0038450': 'stridor',
#  'C0497247': 'arterial pressure NOS increased',
#  'C0398353': 'Hypoventilation',
#  'C0013604': 'edema',
#  'C0023895': 'disease of liver',
#  'C0151904': 'Aspartate Aminotransferase Increase',
#  'C0277925': 'Cold extremities',
#  'C0016382': 'facial flushing',
#  'C0002792': 'anaphylactic reaction',
#  'C0015230': 'eruption',
#  'C0001339': 'acute pancreatitis',
#  'C0032285': 'neumonia',
#  'C0001418': 'adenocarcinoma',
#  'C0009676': 'confusion',
#  'C0162429': 'malnourished',
#  'C0019112': 'haemorrhoids',
#  'C0595939': 'still birth',
#  'C0002871': 'anaemia',
#  'C0013221': 'drug toxicity NOS',
#  'C0750426': 'increased white blood cell count',
#  'C0085584': 'encephalopathy',
#  'C0003123': 'Anorexia',
#  'C0040822': 'tremor',
#  'C0018524': 'Hallucination',
#  'C0024117': 'chronic obstructive airway disease',
#  'C0013144': 'drowsiness',
#  'C0018681': 'Head ache',
#  'C0004601': 'back injury',
#  'C0041834': 'erythema',
#  'C0012569': 'Diplopia',
#  'C0038002': 'enlarged spleen',
#  'C0027404': 'narcolepsy',
#  'C0014863': 'esophageal spasm',
#  'C0267112': 'erosive gastritis',
#  'C0318712': 'gastroenteritis viral',
#  'C0024312': 'Lymphocytes decreased',
#  'C0678222': 'Breast cancer',
#  'C0033774': 'itch',
#  'C0002878': 'haemolytic anaemia',
#  'C0041909': 'upper gastrointestinal bleeding',
#  'C0022346': 'icterus',
#  'C0017160': 'gastroenteritis',
#  'C0030353': 'optic disc edema',
#  'C0851578': 'sleep disorder',
#  'C0036983': 'septic shock',
#  'C0080274': 'bladder retention',
#  'C0003564': 'Aphonia',
#  'C0030193': 'Pain',
#  'C0043117': 'idiopathic thrombocytopenic purpura',
#  'C0032308': 'pneumonia staphylococcal',
#  'C0002170': 'alopecia',
#  'C0009763': 'conjunctivitis',
#  'C0032300': 'lobar pneumonia',
#  'C0017658': 'glomerulonephritis',
#  'C0013295': 'duodenal ulcer',
#  'C0149871': 'deep vein thromboses',
#  'C0023530': 'leucopenia',
#  'C1260880': 'rhinorrhea',
#  'C0006444': 'bursitis',
#  'C0151706': 'bleeding Vaginal',
#  'C0015256': 'Excoriation',
#  'C0035258': 'Ekbom Syndrome',
#  'C0027709': 'nephrocalcinosis',
#  'C0344232': 'blurred vision',
#  'C0034155': 'thrombotic microangiopathy',
#  'C0012833': 'dizziness',
#  'C0032231': 'pleurisy',
#  'C0038814': 'sunburn',
#  'C0019825': 'Hoarseness',
#  'C0265031': 'Bleeding hemorrhoids',
#  'C0015672': 'Fatigue',
#  'C0032290': 'aspiration pneumonia',
#  'C0267566': 'perirectal abscess',
#  'C0011991': 'diarrhea',
#  'C0004096': 'asthma',
#  'C0037284': 'skin lesion',
#  'C0040264': 'tinnitus',
#  'C0037763': 'muscle spasm',
#  'C0016059': 'fib',
#  'C0006840': 'Candida Infection',
#  'C0575081': 'Abnormal Gait',
#  'C0017672': 'glossodynia',
#  'C0016167': 'anal fissure',
#  'C0042769': 'Infection Viral',
#  'C0007642': 'cellulitis',
#  'C0011615': 'allergic dermatitis',
#  'C0009806': 'constipated',
#  'C0005779': 'Clotting',
#  'C0030552': 'muscle paresis',
#  'C0011053': 'deafness',
#  'C0042928': 'vocal cord paralysis',
#  'C0151908': 'dry skin',
#  'C0155540': 'ear discharge',
#  'C0151827': 'eye pain',
#  'C0023418': 'Leukaemia',
#  'C0027092': 'myopia',
#  'C0022661': 'Chronic Kidney Disease',
#  'C0022660': 'acute kidney failure',
#  'C0040485': 'retrocollis',
#  'C0009241': 'cognitive disorder',
#  'C0008311': 'Cholangitis',
#  'C0020676': 'hypothyroid',
#  'C0011603': 'dermatitides',
#  'C0151766': 'Abnormal LFTs',
#  'C0011609': 'dermatitis medicamentosa',
#  'C0011206': 'acute brain syndrome',
#  'C0018784': 'Deafness neurosensory',
#  'C0026946': 'fungal disease',
#  'C0152029': 'nasal sinus congestion',
#  'C0700200': 'Near Syncope',
#  'C0014742': 'erythema multiforme',
#  'C0018944': 'haematoma',
#  'C0005758': 'bleb',
#  'C0027424': 'nasal congestion',
#  'C0002453': 'amenorrhea',
#  'C0014591': 'epistaxis',
#  'C0019158': 'hepatitis',
#  'C0009144': 'coated tongue',
#  'C0027947': 'Neutropenia',
#  'C0043144': 'wheeze',
#  'C0267596': 'haemorrhage rectum',
#  'C0000737': 'abdominal pain',
#  'C0008031': 'chest pain',
#  'C0041296': 'Mycobacterium tuberculosis infection',
#  'C0008350': 'cholelithiasis',
#  'C0034212': 'pyoderma',
#  'C0023055': 'laryngeal neoplasia',
#  'C0018939': 'Blood disorder',
#  'C0033975': 'psychoses',
#  'C0231528': 'aching muscles',
#  'C0000833': 'abscess',
#  'C0041657': 'loss of consciousness',
#  'C0038663': 'attempted suicide',
#  'C0018520': 'bad breath',
#  'C0003869': 'Arthritis infective',
#  'C0043096': 'loss of weight',
#  'C0027441': 'nasopharyngitis',
#  'C0014724': 'belching',
#  'C0035455': 'Rhinitis',
#  'C0022104': 'Colon Spastic',
#  'C0027051': 'heart attack',
#  'C0023903': 'hepatic neoplasia',
#  'C0242528': 'azotaemia',
#  'C0027769': 'nervous tension',
#  'C0151786': 'muscle weakness',
#  'C0085680': 'hypochloraemia',
#  'C0086543': 'cataract',
#  'C0232492': 'abdominal pain upper',
#  'C0917801': 'insomnia',
#  'C0013395': 'dyspepsia',
#  'C0004093': 'asthenia',
#  'C0042963': 'emesis',
#  'C0034065': 'Embolism pulmonary',
#  'C0005424': 'biliary tract disorder',
#  'C0162529': 'colitis ischemic',
#  'C0030196': 'Extremity pain',
#  'C0010054': 'arteriosclerotic heart disease',
#  'C0235329': 'Small intestinal obstruction',
#  'C0030554': 'Paraesthesia',
#  'C0027651': 'neoplasia',
#  'C0039070': 'Fainting',
#  'C0020625': 'blood sodium decreased',
#  'C0037383': 'sneezing',
#  'C0231218': 'Feeling unwell',
#  'C0020621': 'hypokalaemia',
#  'C0024050': 'lower GI bleeding',
#  'C0149931': 'migraine',
#  'C0158252': 'intervertebral disc disorder',
#  'C0029456': 'osteoporosis',
#  'C0020538': 'High blood pressure',
#  'C0221706': 'road traffic accident',
#  'C1510475': 'diverticulosis',
#  'C0003873': 'Arthritis rheumatoid',
#  'C0042798': 'Abnormal vision',
#  'C0003850': 'arteriosclerosis',
#  'C0038999': 'bulging',
#  'C0029408': 'Osteoarthritis',
#  'C0008033': 'pleural pain',
#  'C0017168': 'acid reflux',
#  'C0016053': 'fibromyalgia',
#  'C0024902': 'breast pain',
#  'C0030252': 'palpitation',
#  'C0019360': 'herpes zoster',
#  'C0006144': 'Breast cyst',
#  'C0027080': 'myoglobinuria',
#  'C0029442': 'osteomalacia',
#  'C0036396': 'ischias',
#  'C0003862': 'Aching joints',
#  'C0003864': 'arthritis',
#  'C0013146': 'abuse',
#  'C0009376': 'colonic polyp',
#  'C0008325': 'cholecystitis',
#  'C0231807': 'Dyspnea exertional',
#  'C0151636': 'Extrasystoles Ventricular',
#  'C0035854': 'acne rosacea',
#  'C0042024': 'Incontinence',
#  'C0016977': 'gall bladder',
#  'C0011880': 'diabetic acidosis',
#  'C0011884': 'Diabetic Retinopathy',
#  'C0005741': 'blepharitis',
#  'C0034186': 'pyelonephritis',
#  'C0043352': 'aptyalism',
#  'C0005747': 'Blepharospasm',
#  'C0002940': 'aneurysm',
#  'C0005001': 'benign prostatic hyperplasia',
#  'C0435630': 'wrist fracture',
#  'C0012691': 'dislocation',
#  'C1510431': 'Superficial thrombophlebitis',
#  'C0011124': 'Decreased Libido',
#  'C0011127': 'decubitus ulcer',
#  'C0035078': 'kidney failure',
#  'C0025289': 'meningitides',
#  'C0206062': 'ild',
#  'C0242453': 'prostatism',
#  'C0085614': 'Atrioventricular block first degree',
#  'C0010200': 'Cough',
#  'C0042594': 'Vestibular disorder',
#  'C0086769': 'panic attack',
#  'C0028084': 'nightmare',
#  'C1321523': 'wandering atrial pacemaker',
#  'C0024103': 'Breast Lump',
#  'C0028734': 'nocturia',
#  'C0042571': 'spinning sensation',
#  'C0011849': 'Diabetes',
#  'C0006277': 'bronchitis',
#  'C0032584': 'polyp',
#  'C0029443': 'osteomyelitis',
#  'C0034069': 'lung fibrosis',
#  'C0019209': 'enlarged liver',
#  'C0043246': 'laceration',
#  'C0009421': 'coma',
#  'C0026846': 'amyotrophy',
#  'C0006625': 'cachectic',
#  'C0022679': 'renal cyst',
#  'C0031117': 'neuropathy peripheral',
#  'C0262428': 'collagenvascular disease',
#  'C0004623': 'Bacterial infection',
#  'C0042384': 'angiitis',
#  'C0036572': 'convulsion',
#  'C0162316': 'iron deficiency anaemia',
#  'C0878544': 'Cardiomyopathy',
#  'C0006266': 'bronchial spasm',
#  'C0015802': 'femur fracture',
#  'C0149756': 'fascitis plantar',
#  'C0018802': 'Cardiac decompensation',
#  'C0038362': 'mucositis oral',
#  'C0152031': 'joint swelling',
#  'C0019270': 'hernia',
#  'C0017601': 'glaucoma',
#  'C0026265': 'mitral valve disease NOS',
#  'C0085649': 'edema extremities',
#  'C0149726': 'pulmonary mass',
#  'C0016034': 'breast dysplasia',
#  'C0031542': 'Phlebitis',
#  'C0024121': 'lung neoplasms',
#  'C0575090': 'balance disorder',
#  'C0030312': 'bone marrow failure',
#  'C0011168': 'deglutition disorder',
#  'C0001623': 'adrenal insufficiency',
#  'C0152027': 'sensory disturbance',
#  'C0152025': 'polyneuropathy',
#  'C0392525': 'Nephrolithiasis',
#  'C0013362': 'dysarthria',
#  'C0020651': 'Hypotension Orthostatic',
#  'C0036439': 'Scoliosis',
#  'C0262385': 'autonomic instability',
#  'C0035410': 'rhabdomyolysis',
#  'C0152169': 'renal colic',
#  'C0023211': 'bundle branch block left',
#  'C0038454': 'apoplexy',
#  'C0024523': 'malabsorption',
#  'C0003537': 'aphasia',
#  'C0002622': 'Amnesia',
#  'C0015967': 'body temperature increased',
#  'C0085624': 'burning sensation',
#  'C0085593': 'chill',
#  'C0031511': 'phaeochromocytoma',
#  'C0042029': 'Infection Urinary Tract',
#  'C0028081': 'night sweat',
#  'C0022575': 'keratitis sicca',
#  'C0011175': 'dehydration',
#  'C0004134': 'Ataxia',
#  'C0007787': 'transient ischaemic attack',
#  'C0007784': 'cerebral haemorrhage',
#  'C0011860': 'Mod',
#  'C0020443': 'elevated cholesterol',
#  'C0039231': 'heart rate increased',
#  'C0270996': 'eye swelling',
#  'C0033953': 'psychosexual disorder',
#  'C0003467': 'Anxiety',
#  'C0015469': 'facial palsy',
#  'C0013928': 'fat embolism',
#  'C0041956': 'ureteral obstruction',
#  'C0022658': 'disorder Renal',
#  'C0027719': 'nephrosclerosis',
#  'C0001957': 'delirium tremens',
#  'C0003872': 'psoriatic arthritis',
#  'C0038436': 'post traumatic stress disorder',
#  'C0023067': 'laryngitis',
#  'C0042373': 'angiopathy',
#  'C0021400': 'flu',
#  'C0007570': 'coeliac disease',
#  'C0001546': 'adjustment disorder',
#  'C0024586': 'carcinoid syndrome',
#  'C0027497': 'nausea',
#  'C0973461': 'dysphasia',
#  'C0152128': 'drug withdrawal',
#  'C0032227': 'Pleural Effusion',
#  'C0037199': 'Sinusitis',
#  'C0020433': 'Bilirubinaemia',
#  'C0497327': 'amentia',
#  'C0235946': 'cerebral atrophy',
#  'C0007859': 'cervicalgia',
#  'C0020473': 'hyperlipaemia',
#  'C0006112': 'metabolic encephalopathy',
#  'C0011881': 'Diabetic Nephropathy',
#  'C0014038': 'encephalitis',
#  'C0242362': 'Intervertebral Disc Herniation',
#  'C0004153': 'Atherosclerosis',
#  'C0003504': 'aortic regurgitation',
#  'C0027796': 'Neuralgia',
#  'C0018991': 'hemiplegia',
#  'C0519030': 'pneumonia Klebsiella',
#  'C0034067': 'emphysema',
#  'C0004238': 'AFIB',
#  'C0032768': 'Postherpetic Neuralgia',
#  'C0014457': 'Eosinophil Count Increased',
#  'C0027813': 'Neuritis',
#  'C0522055': 'abnormal ECG',
#  'C0016663': 'Bone Fracture Spontaneous',
#  'C0017574': 'gingivitis',
#  'C0149778': 'soft tissue infection',
#  'C0016242': 'floaters',
#  'C0040136': 'thyroid neoplasia',
#  'C0518988': 'dental abscess',
#  'C0040460': 'dental pain',
#  'C0520474': 'aseptic necrosis bone',
#  'C0006325': 'bruxism',
#  'C0035317': 'retinal bleeding',
#  'C0239739': 'gingival pain',
#  'C0029400': 'bone inflammation',
#  'C0006849': 'candidiasis of mouth',
#  'C0040435': 'tooth disease',
#  'C0221776': 'mouth pain',
#  'C0022408': 'arthropathy',
#  'C0031039': 'pericardial effusion',
#  'C0242379': 'lung neoplasm malignant',
#  'C0021311': 'infection',
#  'C0456909': 'blindness',
#  'C0019348': 'herpes simplex',
#  'C0018965': 'blood in urine',
#  'C0023467': 'Acute myeloblastic leukemia',
#  'C0151611': 'abnormal EEG',
#  'C0017152': 'gastric inflammation',
#  'C0274435': 'Transfusion reaction',
#  'C0000786': 'abortion spontaneous',
#  'C0149801': 'urosepsis',
#  'C0013473': 'eating disorder',
#  'C0036341': 'schizophrenia',
#  'C0018808': 'cardiac murmur',
#  'C0018800': 'cardiac enlargement',
#  'C0033687': 'proteinuria',
#  'C0836924': 'increased platelet count',
#  'C0221150': 'odynophagia',
#  'C0026769': 'multiple sclerosis',
#  'C0042164': 'intraocular inflammation',
#  'C0043094': 'weight gain',
#  'C0014549': 'Convulsions Grand Mal',
#  'C0014394': 'Enuresis',
#  'C0085615': 'bundle branch block right',
#  'C0031212': 'Personality disorder',
#  'C0037023': 'salivary gland inflammation',
#  'C0340274': 'pregnancy induced hypertension',
#  'C0007860': 'cervicitis',
#  'C0019291': 'hernia hiatal',
#  'C0007868': 'cervical dysplasia',
#  'C0024205': 'adenitis',
#  'C0013491': 'ecchymoses',
#  'C0686347': 'tardive dyskinesia',
#  'C0005826': 'blood pressure abnormal',
#  'C0080194': 'muscle strain',
#  'C0042136': 'uterine infection',
#  'C0033038': 'Ejaculation Premature',
#  'C0085602': 'excessive thirst',
#  'C0013456': 'ear ache',
#  'C0151632': 'elevated erythrocyte sedimentation rate',
#  'C0020437': 'Blood Calcium Increased',
#  'C0162298': 'joint stiffness',
#  'C0349231': 'phobia',
#  'C0014868': 'esophagitis',
#  'C0027726': 'nephrotic syndrome',
#  'C0034886': 'proctalgia',
#  'C0151825': 'bone pain',
#  'C0009917': 'contracture',
#  'C0033246': 'proctitis',
#  'C0038012': 'spondylitis',
#  'C0038019': 'spondylosis',
#  'C1384606': 'dyspareunia',
#  'C0020502': 'hyperparathyroidism',
#  'C0037315': 'sleep apnea',
#  'C0034735': 'Raynauds phenomenon',
#  'C0259768': 'wound dehiscence',
#  'C0155773': 'portal vein thrombosis',
#  'C0018674': 'head injury',
#  'C0003708': 'Arachnoiditis',
#  'C0039103': 'synovitis',
#  'C0020458': 'hyperhidrosis',
#  'C0028738': 'nystagmus',
#  'C0017181': 'gastrointestinal bleed',
#  'C0003635': 'apraxia',
#  'C0232726': 'Rectal Tenesmus',
#  'C0002726': 'amyloidosis',
#  'C1510472': 'Drug addiction',
#  'C0033581': 'prostatitis',
#  'C0015806': 'femoral neck fracture',
#  'C0037672': 'sleep walking',
#  'C1136085': 'monoclonal gammopathy',
#  'C0009938': 'bruise',
#  'C0008767': 'Scar',
#  'C0018799': 'cardiac disease',
#  'C0030794': 'pain pelvic',
#  'C0019557': 'hip fracture',
#  'C0311394': 'difficulty in walking',
#  'C0030319': 'panic disorder',
#  'C0018817': 'atrial septal defect',
#  'C0039503': 'Tendinitis',
#  'C0178879': 'obstructive uropathy',
#  'C0042267': 'Colpitis',
#  'C0221245': 'Rhagades',
#  'C1442903': 'bone spur',
#  'C0030305': 'pancreatitis',
#  'C0002103': 'allergic rhinitis',
#  'C0029882': 'otitis media',
#  'C0016807': 'intestinal functional disorder',
#  'C0015732': 'faecal incontinence',
#  'C0007286': 'carpal tunnel',
#  'C0018932': 'haematochezia',
#  'C0021141': 'ADH inappropriate',
#  'C0442874': 'neuropathy',
#  'C0149725': 'Chest infection',
#  'C0700594': 'radiculopathy',
#  'C1527344': 'dysphonia',
#  'C0037928': 'myelopathy',
#  'C0025222': 'black stools',
#  'C0013428': 'dysuria',
#  'C0085635': 'flashing lights',
#  'C0342579': 'Electrolyte disorder',
#  'C1384666': 'Decreased hearing',
#  'C0026267': 'mitral valve prolapse',
#  'C0015695': 'fatty liver',
#  'C0029163': 'mouth bleeding',
#  'C0005586': 'bipolar disorder',
#  'C0013922': 'embolism',
#  'C0013298': 'duodenitis',
#  'C0025202': 'malignant melanoma',
#  'C0699744': 'ear infection',
#  'C0085610': 'sinus bradycardia',
#  'C0033036': 'atrial ectopic beats',
#  'C0029878': 'external ear infection',
#  'C0027121': 'muscle inflammation',
#  'C0262414': 'cervical vertebral fracture',
#  'C0020295': 'hydronephrosis',
#  'C0011334': 'dental caries',
#  'C0178415': 'elevated prostate specific antigen',
#  'C0149745': 'mouth ulcer',
#  'C0030920': 'gastroduodenal ulcer',
#  'C0016169': 'fistula',
#  'C0149514': 'acute bronchitis',
#  'C0018418': 'gynaecomastia',
#  'C0085682': 'Hypophosphataemia',
#  'C0020461': 'Excess potassium',
#  'C0151970': 'esophageal ulcer',
#  'C0001126': 'renal tubular acidosis',
#  'C0042487': 'phlebothrombosis',
#  'C0392699': 'dysaesthesia',
#  'C0018021': 'goiter',
#  'C0220983': 'metabolic alkalosis',
#  'C0497156': 'Adenopathy',
#  'C0206504': 'tympanic membrane perforation',
#  'C0003811': 'Arrhythmia',
#  'C0085605': 'Hepatic failure',
#  'C0020505': 'hyperalimentation',
#  'C0080179': 'Spinal fracture',
#  'C0242422': 'Parkinson',
#  'C0026650': 'movement disorder',
#  'C0024437': 'macula lutea degeneration',
#  'C0026858': 'musculoskeletal pain',
#  'C0033931': 'psychosomatic disease',
#  'C0151744': 'Cardiac ischemia',
#  'C1456784': 'paranoia',
#  'C0035304': 'retinal degeneration',
#  'C0149516': 'chronic sinusitis',
#  'C0041582': 'ulcer',
#  'C0035522': 'rib fracture',
#  'C0263912': 'rotator cuff syndrome',
#  'C0021099': 'impetigo',
#  'C0149531': 'fractured pelvis NOS',
#  'C0041912': 'Infection Upper Respiratory',
#  'C0002994': 'angioedema',
#  'C0037052': 'sick sinus syndrome',
#  'C0020550': 'hyperthyroidism',
#  'C0018801': 'cardiac failure',
#  'C0264906': 'atrioventricular block second degree',
#  'C0031350': 'pharyngeal inflammation',
#  'C0001430': 'adenoma',
#  'C0014544': 'epilepsy',
#  'C0178428': 'sinus arrest',
#  'C0002962': 'angina',
#  'C0026848': 'muscle disorder',
#  'C0006384': 'bundle branch block',
#  'C0042514': 'tachycardia ventricular',
#  'C0027962': 'melanocytic naevus',
#  'C0026821': 'cramp',
#  'C0004239': 'atrial flutter',
#  'C0036974': 'cardiovascular collapse',
#  'C0020488': 'hypernatraemia',
#  'C0042109': 'hive',
#  'C0027022': 'MPD',
#  'C0042420': 'syncope vasovagal',
#  'C0038395': 'streptococcal infection',
#  'C0004030': 'aspergillosis',
#  'C0085636': 'Light sensitivity',
#  'C0014335': 'enteritis',
#  'C0005961': 'bone marrow transplant',
#  'C0149925': 'SCLC',
#  'C0009319': 'colitis',
#  'C0020557': 'elevated triglycerides',
#  'C0271650': 'Glucose intolerance',
#  'C0026764': 'Multiple Myeloma',
#  'C0151966': 'duodenal ulcer haemorrhage',
#  'C0010823': 'CMV infection',
#  'C0018989': 'hemiparesis',
#  'C0085655': 'polymyositis',
#  'C0004610': 'Bacteraemia',
#  'C0040261': 'onychomycosis',
#  'C0699790': 'carcinoma of the colon',
#  'C0152086': 'traumatic arthropathy',
#  'C0027059': 'myocarditis',
#  'C0018824': 'cardiac valvulopathy',
#  'C0014118': 'endocarditis',
#  'C0151517': 'Atrioventricular block complete',
#  'C0042510': 'ventricular fibrillation',
#  'C0017086': 'gangrene',
#  'C0022116': 'ischaemia',
#  'C0041755': 'ADVERSE DRUG EFFECT',
#  'C0426636': 'defaecation urgency',
#  'C0023890': 'cirrhosis',
#  'C0040997': 'trigeminal neuralgia',
#  'C0019917': 'hordeolum',
#  'C0032617': 'polyuria',
#  'C0031090': 'periodontal disease',
#  'C0028754': 'obesity',
#  'C0017979': 'glucosuria',
#  'C0007117': 'basal cell carcinoma',
#  'C0162297': 'pulmonary arrest',
#  'C0018926': 'haematemesis',
#  'C0018188': 'granuloma',
#  'C0025287': 'meningeal irritation',
#  'C0036117': 'Salmonella',
#  'C0011854': 'insulin dependent diabetes mellitus',
#  'C0015544': 'failure to thrive',
#  'C0007177': 'Cardiac tamponade',
#  'C0159877': 'ankle fracture',
#  'C0019193': 'hepatitis toxic',
#  'C0014130': 'endocrine disorder',
#  'C0037195': 'Sinus headache',
#  'C0151465': 'renal abscess',
#  'C0012813': 'diverticulitis',
#  'C0011606': 'dermatitis exfoliative',
#  'C0038353': 'gastric dilatation',
#  'C0005687': 'distended bladder',
#  'C0149521': 'pancreatitis relapsing',
#  'C0040046': 'Thrombophlebitis',
#  'C0235761': 'nasal septal perforation',
#  'C0037011': 'shoulder pain',
#  'C0438215': 'Abnormal Laboratory Findings',
#  'C0032371': 'Polio',
#  'C0740401': 'duodenal ulcer perforation',
#  'C1253936': 'joint effusion',
#  'C0018818': 'ventricular septal defect',
#  'C0003868': 'gouty arthritis',
#  'C0039240': 'Supraventricular tachycardia',
#  'C0002064': 'respiratory alkalosis',
#  'C0151699': 'haemorrhage intracranial',
#  'C1269683': 'major depression',
#  'C0917799': 'excessive sleepiness',
#  'C0024299': 'lymphoma',
#  'C0740858': 'substance abuse',
#  'C0003044': 'animal bite',
#  'C0007820': 'cerebral vascular disorder',
#  'C0314719': 'dry eye',
#  'C0029927': 'Ovarian Cyst',
#  'C0085606': 'micturition urgency',
#  'C0042025': 'Stress incontinence',
#  'C0152032': 'hesitancy',
#  'C0016658': 'bone fracture',
#  'C0028259': 'nodule',
#  'C0010709': 'cyst',
#  'C0178282': 'Abdominal hernia',
#  'C0036421': 'Scleroderma',
#  'C0034072': 'Cor pulmonale',
#  'C0037036': 'excessive salivation',
#  'C0235527': 'right heart failure',
#  'C0038525': 'subarachnoid haemorrhage',
#  'C0006826': 'cancer',
#  'C0037578': 'soft tissue injuries',
#  'C1257843': 'colitis pseudomembranous',
#  'C0025323': 'heavy menstrual period',
#  'C0025322': 'premature menopause',
#  'C0019322': 'umbilical hernia',
#  'C0033860': 'psoriasis',
#  'C0011616': 'contact dermatitis',
#  'C0005745': 'blepharoptosis',
#  'C0017565': 'Bleeding gums',
#  'C0014488': 'epicondylitis',
#  'C0027343': 'ingrowing nail',
#  'C0036508': 'dermatitis seborrheic',
#  'C0006852': 'candidiasis of vagina',
#  'C0262431': 'Spinal Compression Fracture',
#  'C0522224': 'palsies',
#  'C0014553': 'petit mal',
#  'C0018099': 'gout',
#  'C0917798': 'cerebral ischaemia',
#  'C0015423': 'eyelid diseases',
#  'C0038358': 'gastric ulcer',
#  'C0031099': 'periodontitis',
#  'C0014518': 'Lyell',
#  'C0022603': 'seborrhoeic keratosis',
#  'C0022602': 'actinic keratosis',
#  'C0008301': 'choking',
#  'C0032633': 'dyshidrosis',
#  'C0003507': 'aortic stenosis',
#  'C0019079': 'coughing blood',
#  'C0206063': 'radiation pneumonitis',
#  'C0017675': 'Glossitis',
#  'C0004626': 'bacterial pneumonia',
#  'C0001948': 'alcohol consumption',
#  'C0553723': 'squamous cell carcinoma of skin',
#  'C0235974': 'pancreatic cancer',
#  'C0039520': 'Tenosynovitis',
#  'C0023885': 'liver abscess',
#  'C0026986': 'myelodysplasia',
#  'C0034887': 'rectal polyp',
#  'C0006107': 'brain concussion',
#  'C0037299': 'cutaneous ulcer',
#  'C0232943': 'menometrorrhagia',
#  'C0015468': 'face pain',
#  'C0004245': 'atrioventricular block',
#  'C0020565': 'breast enlargement',
#  'C0271468': 'Eustachian tube disorder',
#  'C0024421': 'macroglossia',
#  'C0236720': 'flashbacks',
#  'C0149512': 'acute sinusitis',
#  'C0242172': 'Pelvic Inflammatory Disease',
#  'C0278008': 'Altered Bowel Function',
#  'C0151480': 'antinuclear antibody positive',
#  'C0235660': 'galactorrhea',
#  'C0036337': 'schizoaffective disorder',
#  'C0006012': 'borderline personality disorder',
#  'C0027531': 'injury of neck',
#  'C0036689': 'Pharyngitis Streptococcal',
#  'C0162283': 'Nephrogenic diabetes insipidus',
#  'C0151798': 'hepatic necrosis',
#  'C0020541': 'portal hypertension',
#  'C0011882': 'Diabetic neuropathy',
#  'C0006118': 'brain neoplasm',
#  'C0014869': 'reflux esophagitis',
#  'C0025874': 'Breakthrough bleeding',
#  'C0018500': 'hair disease',
#  'C0262627': 'Seroma',
#  'C0158328': 'trigger finger',
#  'C0027707': 'Interstitial nephritis',
#  'C0027339': 'Nail disorder',
#  'C0151436': 'allergic vasculitis',
#  'C0023646': 'lichen planus',
#  'C0022572': 'keratoacanthomas',
#  'C0345996': 'milia',
#  'C0007282': 'carotid artery stenosis',
#  'C0236048': 'gastric polyps',
#  'C0870082': 'hyperkeratosis',
#  'C0600327': 'toxic shock',
#  'C0011649': 'dermoid cyst',
#  'C0085580': 'essential hypertension',
#  'C0019163': 'hepatitis B',
#  'C0039685': 'tetralogy of Fallot',
#  'C0152021': 'congenital heart disease',
#  'C0149709': 'hepatitis B surface antigen positive',
#  'C0009375': 'colon neoplasm',
#  'C0008320': 'cholecystectomies',
#  'C0600139': 'Carcinoma of Prostate',
#  'C0085619': 'orthopnea',
#  'C0262613': 'renal mass',
#  'C0006145': 'Breast disorder',
#  'C0024141': 'disseminated lupus erythematosus',
#  'C0085661': 'Onycholysis',
#  'C0262397': 'breast tenderness',
#  'C0026272': 'mixed connective tissue disease',
#  'C0149741': 'breast discharge',
#  'C0085096': 'Disorder Peripheral Vascular',
#  'C0206762': 'limb malformation',
#  'C0020514': 'Hyperprolactinaemia',
#  'C1261470': 'meningocele',
#  'C0281774': 'acute psychosis',
#  'C0220982': 'ketoacidosis',
#  'C0036202': 'sarcoidosis',
#  'C0035305': 'Detached retina',
#  'C1527407': 'eosinophilic pneumonia',
#  'C0008035': 'Chest wall pain',
#  'C0272386': 'tonsillar hypertrophy',
#  'C0000889': 'acanthosis nigricans',
#  'C0162834': 'hyperpigmentation',
#  'C0040213': 'costochondritis',
#  'C0001818': 'agoraphobia',
#  'C0221264': 'cheilosis',
#  'C0423798': 'Easy bruisability',
#  'C0029134': 'OPTIC NEURITIS',
#  'C0015408': 'eye injury',
#  'C0036454': 'scotoma',
#  'C0013595': 'eczema',
#  'C0040590': 'tracheostomy',
#  'C0149732': 'Muscle Rupture',
#  'C0029463': 'bone sarcoma',
#  'C0027819': 'neuroblastoma',
#  'C0025063': 'mediastinal tumor',
#  'C0014733': 'erysipelas',
#  'C0221166': 'paraparesis',
#  'C0242225': 'color blindness',
#  'C0019212': 'hepatorenal syndrome',
#  'C0019196': 'Hepatitis C',
#  'C0015403': 'eye infection',
#  'C0149678': 'EBV infection',
#  'C0007876': 'Caesarean Section',
#  'C0001824': 'agranulocytoses',
#  'C0031256': 'petechia',
#  'C0018946': 'hematoma subdural',
#  'C0017638': 'glioma',
#  'C0085652': 'pyoderma gangrenosum',
#  'C0033845': 'benign intracranial hypertension',
#  'C0007780': 'cerebral artery embolism',
#  'C0020255': 'hydrocephalus',
#  'C0086438': 'hypogammaglobulinaemia',
#  'C0702166': 'Acne',
#  'C0020540': 'malignant hypertension',
#  'C0271429': 'acute otitis media',
#  'C0032781': 'Post nasal drip',
#  'C0022893': 'labyrinthitis',
#  'C0037287': 'Nodule Skin',
#  'C0151514': 'atrophy of skin',
#  'C0149736': 'neck mass',
#  'C0040584': 'tracheitis',
#  'C0341858': 'adenomyosis',
#  'C0035439': 'rheumatic heart disease',
#  'C0042870': 'Vitamin D Deficiency',
#  'C0558489': 'kidney pain',
#  'C0740394': 'hyperuricaemia',
#  'C0037995': 'splenectomy',
#  'C0026919': 'atypical mycobacterial infection',
#  'C0030583': 'parotitis',
#  'C0085583': 'choreoathetosis',
#  'C0035309': 'Disorder Retinal',
#  'C0031046': 'pericarditis',
#  'C0021092': 'cerumen impaction',
#  'C0042900': 'vitiligo',
#  'C0030578': 'paronychia',
#  'C0009410': 'colostomy',
#  'C0040456': 'Tooth Impacted',
#  'C0040128': 'thyroid disease',
#  'C0003486': 'aortic aneurysm',
#  'C0011633': 'dermatomyositis',
#  'C0020453': 'hyperaesthesia',
#  'C0002736': 'als',
#  'C0007789': 'cerebral palsy',
#  'C0085666': 'spider angioma',
#  'C0006267': 'bronchiectasis',
#  'C0151620': 'encephalopathy hypertensive',
#  'C0271036': 'retinal scar',
#  'C0034902': 'aplasia pure red cell',
#  'C0002884': 'anaemia hypochromic',
#  'C0242301': 'furuncle',
#  'C0031111': 'periostitis',
#  'C0000768': 'birth defect',
#  'C0007758': 'cerebellar ataxia',
#  'C0259749': 'autonomic neuropathy',
#  'C0010034': 'corneal disorder',
#  'C0032533': 'polymyalgia rheumatica',
#  'C0019284': 'diaphragmatic hernia',
#  'C0024236': 'lymphedema',
#  'C0010055': 'coronary artery bypass graft',
#  'C0264545': 'pleural fibrosis',
#  'C0039483': 'temporal arteritis',
#  'C0162323': 'polyarthritis',
#  'C0031538': 'phimosis',
#  'C0022904': 'Lacrimal Disorder',
#  'C0266813': 'fecal occult blood',
#  'C0149520': 'cholecystitis acute',
#  'C0021390': 'inflammatory bowel disease',
#  'C0039504': 'tendon injury',
#  'C0002963': 'Prinzmetal variant angina',
#  'C0019521': 'hiccough',
#  'C0036830': 'serum sickness',
#  'C0001175': 'acquired immune deficiency syndrome',
#  'C0002874': 'Anemia aplastic',
#  'C0006105': 'brain abscess',
#  'C0085648': 'synovial cyst',
#  'C0032987': 'ectopic pregnancies',
#  'C0030354': 'Papilloma',
#  'C0032302': 'pneumonia primary atypical',
#  'C0152132': 'retinopathy hypertensive',
#  'C0029925': 'Ovarian cancer',
#  'C0152013': 'lung adenocarcinoma',
#  'C0699791': 'Gastric Cancer',
#  'C0040247': 'tinea',
#  'C0042345': 'varicose vein',
#  'C0031925': 'pilonidal cyst',
#  'C0010666': 'cystic acne',
#  'C0038363': 'aphthous stomatitis',
#  'C0040252': 'body tinea',
#  'C0032580': 'familial adenomatous polyposis',
#  'C0151971': 'intestinal ulcer',
#  'C0011630': 'Cutaneous mycosis',
#  'C0009186': 'coccidioidomycosis',
#  'C0020162': 'humerus fracture',
#  'C0042961': 'volvulus',
#  'C0027868': 'Neuromuscular Disorder',
#  'C0227791': 'vaginal discharge',
#  'C0851886': 'Pneumocystis carinii infection',
#  'C0022548': 'Keloid scar',
#  'C0008312': 'primary biliary cirrhosis',
#  'C0149721': 'left ventricular hypertrophy',
#  'C0149684': 'colon polypectomy',
#  'C0003126': 'anosmia',
#  'C0039621': 'tetany',
#  'C0476427': 'abnormal cervical smear',
#  'C0018916': 'haemangioma',
#  'C0267716': 'incisional hernia',
#  'C0262365': 'abnormal mammogram',
#  'C0003874': 'Arthritis bacterial',
#  'C0037998': 'Splenic infarction',
#  'C0019294': 'Hernia Inguinal',
#  'C0025286': 'meningioma',
#  'C0032305': 'Pneumocystis carinii pneumonia',
#  'C0750876': 'phlebitis superficial',
#  'C0262493': 'gallbladder polyp',
#  'C0156181': 'peritoneal adhesions',
#  'C1510471': 'hypovitaminosis',
#  'C0019151': 'hepatic encephalopathy',
#  'C0013405': 'Dyspnoea paroxysmal nocturnal',
#  'C0007280': 'carotid bruit',
#  'C0042847': 'vitamin B 12 deficiency',
#  'C0020258': 'normal pressure hydrocephalus',
#  'C0030486': 'paraplegia',
#  'C0010036': 'Corneal dystrophy',
#  'C0025290': 'Aseptic meningitis',
#  'C0001969': 'Alcoholic intoxication',
#  'C0007462': 'causalgia',
#  'C0152030': 'Irritation Skin',
#  'C0079035': 'Bradyarrhythmia',
#  'C0009946': 'conversion disorder',
#  'C0270629': 'epidural abscess',
#  'C0085694': 'cholecystitis chronic',
#  'C0282005': 'swollen scrotum',
#  'C0018621': 'hay fever',
#  'C0026896': 'myasthenia gravis',
#  'C0042133': 'fibroids',
#  'C0038833': 'superior vena cava syndrome',
#  'C0025061': 'mediastinal disorder',
#  'C0699885': 'bladder cancer',
#  'C0034372': 'quadriplegia',
#  'C0001925': 'albuminuria',
#  'C0006152': 'Breast swelling',
#  'C0033578': 'neoplasm prostate',
#  'C0034050': 'alveolar proteinosis',
#  'C0026987': 'Bone marrow fibrosis',
#  'C0019655': 'histoplasmosis',
#  'C0039446': 'telangiectases',
#  'C0035436': 'Rheumatic fever',
#  'C0027822': 'neurodermatitis',
#  'C0178421': 'fibroadenoma of breast',
#  'C1258666': 'ganglion',
#  'C0016470': 'food allergy',
#  'C0041976': 'urethritis',
#  'C0152149': 'ovulation pain',
#  'C0085166': 'bacterial vaginitis',
#  'C0019572': 'hirsuitism',
#  'C1527336': 'Sjogrens syndrome',
#  'C0042907': 'vitreous detachment',
#  'C0042909': 'Vitreous haemorrhage',
#  'C0042485': 'venous insufficiency',
#  'C0151790': 'nasal septum disorder',
#  'C0302592': 'carcinoma of the cervix',
#  'C0332687': 'Burns Second Degree',
#  'C0033893': 'tension headache',
#  'C0262578': 'night cramps',
#  'C0549567': 'pigmentation disorder',
#  'C0022568': 'keratitis',
#  'C0022671': 'kidney transplant',
#  'C0011848': 'diabetes insipidus',
#  'C0016665': 'fracture nonunion',
#  'C0007078': 'carbuncle',
#  'C0016436': 'folliculitis',
#  'C0022353': 'jaundice neonatal',
#  'C0014009': 'empyema',
#  'C0008924': 'cleft lip',
#  'C0341163': 'Gastric ulcer perforated',
#  'C0005818': 'platelet disorder',
#  'C0156215': 'gallbladder perforation',
#  'C1322281': 'Rhinitis Seasonal',
#  'C0002390': 'allergic alveolitis',
#  'C0006846': 'cutaneous candidiasis',
#  'C0009324': 'chronic ulcerative colitis',
#  'C0025297': 'Meningitis Viral',
#  'C0205929': 'Anal fistula',
#  'C0152018': 'esophageal cancer',
#  'C0553662': 'JRA',
#  'C0020252': 'hydrocele',
#  'C0022081': 'iritis',
#  'C0007933': 'chalazion',
#  'C0003834': 'arterial insufficiency',
#  'C0005697': 'neurogenic bladder',
#  'C0027430': 'nasal polyp',
#  'C0042134': 'uterine bleeding',
#  'C0156369': 'Uterine polyp',
#  'C0281914': 'musculoskeletal deformity',
#  'C0158570': 'vascular anomaly',
#  'C0040425': 'tonsillitis',
#  'C0034880': 'hyperacusia',
#  'C0014356': 'enterocolitis',
#  'C0424230': 'motor retardation',
#  'C0010414': 'cryptococcosis',
#  'C0038238': 'Fatty stools',
#  'C0033117': 'priapism',
#  'C0043145': 'Whiplash Injury',
#  'C0238154': 'epidural hematoma',
#  'C0035302': 'Retinal artery occlusion',
#  'C0027858': 'neuroma',
#  'C0019189': 'chronic hepatitis',
#  'C0149696': 'food intolerance',
#  'C0009088': 'cluster headache',
#  'C0026948': 'mycosis fungoides',
#  'C0009782': 'connective tissue disease',
#  'C0085662': 'macrocytosis',
#  'C0040147': 'thyroiditis',
#  'C0003079': 'Anisocoria',
#  ...}

# %% [markdown]
# # Basic Statistics

# %% [markdown]
# ## How many side effects does each drug combination have?

# %%
def plot_distribution(dist, title="", x_label="", y_label="", file_name=None):
    plt.figure(figsize=(6, 3.5))
    sns.set_context("paper", font_scale=1.8)
    sns.set_style('ticks')
    sns.set_style({"xtick.direction": "in", "ytick.direction": "in"})
    sns.distplot(dist, kde=False, color=sns.xkcd_rgb['red'], bins=20, hist_kws={"alpha" : 1})
    plt.xlabel(x_label)
    plt.title(title)
    plt.tight_layout()
    plt.gcf().subplots_adjust(left=0.2, right=0.8, top=0.8, bottom=0.2)
    plt.ylabel(y_label)
    if file_name:
        plt.savefig(file_name)

# %%
distribution_combos = [len(combo2se[combo]) for combo in combo2se]
print ("Median number of side effects per drug combination", np.median(distribution_combos))
plot_distribution(distribution_combos, "", "Number of Side Effects", "Number of \n Drug Combinations", "")
# Out:
# Median number of side effects per drug combination 53.0

# %% [markdown]
# ## How frequent are different side effects?

# %%
from IPython.display import display, HTML

def get_se_counter(se_map):
    side_effects = []
    for drug in se_map:
        side_effects += list(set(se_map[drug]))
    return Counter(side_effects)

combo_counter = get_se_counter(combo2se)

print("Most common side effects in drug combinations:")
common_se = []
common_se_counts = []
common_se_names = []
for se, count in combo_counter.most_common(20):
    common_se += [se]
    common_se_counts += [count]
    common_se_names += [se2name[se]]
df = pd.DataFrame(data={"Side Effect": common_se, "Frequency in Drug Combos": common_se_counts, "Name": common_se_names})  
display(df)
# Out:
# Most common side effects in drug combinations:
#     Frequency in Drug Combos                             Name Side Effect
# 0                      28568  arterial pressure NOS decreased    C0020649
# 1                      27006                          anaemia    C0002871
# 2                      26037             Difficulty breathing    C0013404
# 3                      25190                           nausea    C0027497
# 4                      24430                         neumonia    C0032285
# 5                      24260                          Fatigue    C0015672
# 6                      23894                             Pain    C0030193
# 7                      23848                         diarrhea    C0011991
# 8                      23515                         asthenia    C0004093
# 9                      23043                           emesis    C0042963
# 10                     21981                edema extremities    C0085649
# 11                     21806       body temperature increased    C0015967
# 12                     21781                     pleural pain    C0008033
# 13                     21410                   abdominal pain    C0000737
# 14                     21322                  Hypoventilation    C0398353
# 15                     21013                       chest pain    C0008031
# 16                     20204                        dizziness    C0012833
# 17                     19930                        Back Ache    C0004604
# 18                     19803                        Head ache    C0018681
# 19                     19376              High blood pressure    C0020538

# %% [markdown]
# ### Plot of Side Effect Frequency

# %%
plot_distribution(np.log10(np.asarray(list(zip(*combo_counter.items())[1]))), "",  "Log(Number of Drug Combinations)", "Number of Side Effects", file_name="se_combodist.pdf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-046c5fea79e7> in <module>
# ----> 1 plot_distribution(np.log10(np.asarray(list(zip(*combo_counter.items())[1]))), "",  "Log(Number of Drug Combinations)", "Number of Side Effects", file_name="se_combodist.pdf")
#
# TypeError: 'zip' object is not subscriptable

# %% [markdown]
# # Side Effect Cooccurrence in Drug Combinations

# %%
combos = combo2se.keys()
combo_probability_distribution = np.asarray([len(combo2se[combo])*1.0 for combo in combo2se])
combo_probability_distribution = combo_probability_distribution/np.sum(combo_probability_distribution)

se2combo = defaultdict(set)
for combo in combo2se:
    for se in combo2se[combo]:
        se2combo[se].add(combo)

# %% [markdown]
# We observe that polypharmacy side effects do not appear independently of one another in co-prescribed drug pairs (\ie, drug combinations), suggesting that joint modeling over multiple side effects can aid in the prediction task. To quantify the co-occurrence between side effects, we count the number of drug combinations in which a given side effect co-occurs with other side effects, and then use permutation testing with a null model of random co-occurrence. As exemplified for hypertension and nausea below, we find that the majority of the most common side effects are either significantly overrepresented or underrepresented with respect to how often they co-occur with nausea/hypertension as side effects in drug combinations, at $\alpha=0.05$.

# %%
# Permutation test testing the significancy between the drug combinations a side effect occurs in,
# as compared to other common side effects
def run_permutation_test(se_oi, num_permutations = 2000):
    se_oi_combos = se2combo[se_oi]
    side_effects = []
    names = []
    real_overlaps = []
    mean_permuted_overlap = []
    probabilities = []
    for se, count in combo_counter.most_common(51):
        if se == se_oi:
            continue
        real_combos = se2combo[se]
        real_overlap = len(real_combos.intersection(se_oi_combos))
        permuted_overlaps = []
        for i in range(num_permutations):
            combo_sample = np.random.choice(combos, len(real_combos), replace=False, p=combo_probability_distribution)
            permuted_overlaps += [len(se_oi_combos.intersection(set(combo_sample)))]
        probability = np.sum(np.asarray(permuted_overlaps) >= real_overlap)*1.0/num_permutations
        side_effects += [se]
        names += [se2name[se]]
        real_overlaps += [real_overlap]
        mean_permuted_overlap += [np.mean(permuted_overlaps)]
        probabilities += [probability]
    df = pd.DataFrame(data={"Side Effect": side_effects, "True Overlap": real_overlaps, "Mean Permuted Overlap": mean_permuted_overlap, "Probability True < Permuted": probabilities, "Name": names})  
    df = df[['Side Effect', 'Name', 'True Overlap', 'Mean Permuted Overlap', 'Probability True < Permuted']]
    display(df)

# %%
# For hypertension
run_permutation_test('C0020538')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# mtrand.pyx in mtrand.RandomState.choice()
#
# TypeError: 'dict_keys' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0720a5180b8f> in <module>
#       1 # For hypertension
# ----> 2 run_permutation_test('C0020538')
#
# <ipython-input-17-6f5f73ca6937> in run_permutation_test(se_oi, num_permutations)
#      15         permuted_overlaps = []
#      16         for i in range(num_permutations):
# ---> 17             combo_sample = np.random.choice(combos, len(real_combos), replace=False, p=combo_probability_distribution)
#      18             permuted_overlaps += [len(se_oi_combos.intersection(set(combo_sample)))]
#      19         probability = np.sum(np.asarray(permuted_overlaps) >= real_overlap)*1.0/num_permutations
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: 'a' must be 1-dimensional or an integer

# %%
# For nausea
run_permutation_test('C0027497')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# mtrand.pyx in mtrand.RandomState.choice()
#
# TypeError: 'dict_keys' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0299468df4f1> in <module>
#       1 # For nausea
# ----> 2 run_permutation_test('C0027497')
#
# <ipython-input-17-6f5f73ca6937> in run_permutation_test(se_oi, num_permutations)
#      15         permuted_overlaps = []
#      16         for i in range(num_permutations):
# ---> 17             combo_sample = np.random.choice(combos, len(real_combos), replace=False, p=combo_probability_distribution)
#      18             permuted_overlaps += [len(se_oi_combos.intersection(set(combo_sample)))]
#      19         probability = np.sum(np.asarray(permuted_overlaps) >= real_overlap)*1.0/num_permutations
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: 'a' must be 1-dimensional or an integer

# %% [markdown]
# # How similar are the drug target profiles of drug combinations?

# %% [markdown]
# Third, we probe the relationship between proteins targeted by a drug pair and occurrence of side effects. Let $T_i$ represent a set of target proteins associated with drug $i$, we then calculate the Jaccard similarity between target proteins of a given drug pair $(i,j)$ as: $\text{Jaccard}(i,j) = |T_i \cap T_j|/|T_i \cup T_j|$.
# We see most drug combinations have zero target proteins in common, random drug pairs have smaller overlap in targeted proteins than co-prescribed drugs, andthat this trend is unequally observed across different side effects.

# %%
def jaccard(set1, set2):
    num = len(set(set1).intersection(set(set2)))
    den = len(set(set1).union(set(set2)))
    return num*1.0/den

# Only examining those drugs we have drug target information for
valid = []
for stitch in stitch2se:
    if len(stitch2proteins[stitch]) > 0:
        valid += [stitch]
        
# Jaccard similarity between drug target profiles of drugs in drug combinations
jaccard_combos = {}
for combo in combo2se:
    stitch1, stitch2 = combo2stitch[combo]
    if stitch1 in valid and stitch2 in valid:
        jaccard_combos[combo] = jaccard(stitch2proteins[stitch1], stitch2proteins[stitch2])
        
# Jaccard similarity between drug target profiles of random drugs
jaccard_random = []
for i in range(len(jaccard_random)):
    stitch1 = np.random.choice(valid, 1, replace=False)[0]
    stitch2 =  np.random.choice(valid, 1, replace=False)[0]
    jaccard_random += [jaccard(stitch2proteins[stitch1], stitch2proteins[stitch2])] 
jaccard_random = np.asarray(jaccard_random)

# %%
import pandas as pd

def plot_jaccard_distribution_multiple(ses):
    group_names = {'Random drug pairs': jaccard_random, 'All drug combinations': np.asarray([jaccard_combos[combo] for combo in jaccard_combos])}
    order = ['Random drug pairs', 'All drug combinations'] + [nicknames[se] for se in ses]
    for se in ses:
        se_combos = se2combo[se].intersection(set(jaccard_combos.keys()))
        in_jaccard = np.asarray([jaccard_combos[combo] for combo in se_combos])
        group_name = nicknames[se]
        group_names[group_name] = in_jaccard
    categories = {'No shared drug targets': (-.01, 0), 'Fewer than 50% shared': (0, 0.5), 'More than 50% shared':(0.5, 1)}
    groups, similarities, fractions = [], [], []
    for name in group_names:
        arr = group_names[name]
        for category in categories: 
            min_val, max_val = categories[category]
            value = np.sum((arr > min_val) * (arr <= max_val))*1.0/len(arr)
            groups += [name]
            similarities += [category]
            fractions += [value]
    data = pd.DataFrame({ '' : groups, 'Jaccard Similarity Between Drug Target Profiles': similarities, 'Fraction of Drug Combinations': fractions})
    plt.figure(figsize=(3, 5))
    sns.set_context("paper", font_scale=6)
    sns.set_style('ticks')
    sns.set_style({"xtick.direction": "in", "ytick.direction": "in"})
    g = sns.factorplot(x="Jaccard Similarity Between Drug Target Profiles", y="Fraction of Drug Combinations", hue="", data=data,
                   size=18, kind="bar", palette=['#535456', '#9ea3a8', '#3478e5', '#e74c3c', '#2ecc71', '#cc6c18', '#9b59b6',], x_order=['No shared drug targets','Fewer than 50% shared','More than 50% shared'], hue_order=order)
    plt.tight_layout()
    plt.xlabel('')
    plt.savefig('multiple_dist.pdf')

# %%
nicknames = {'C0035522': 'Rib fracture', 'C0001339': 'Acute pancreatitis', 'C0010200': 'Cough', 'C0021390': 'Inflammatory bowel disease', 'C0020538': 'High blood pressure'}

plot_jaccard_distribution_multiple(['C0035522', 'C0001339',  'C0010200', 'C0021390', 'C0020538'])
# Out:
# /home/mamonteiro/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars
# /home/mamonteiro/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/mamonteiro/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-c79a9124844f> in <module>
#       1 nicknames = {'C0035522': 'Rib fracture', 'C0001339': 'Acute pancreatitis', 'C0010200': 'Cough', 'C0021390': 'Inflammatory bowel disease', 'C0020538': 'High blood pressure'}
#       2
# ----> 3 plot_jaccard_distribution_multiple(['C0035522', 'C0001339',  'C0010200', 'C0021390', 'C0020538'])
#
# <ipython-input-22-b6a08c7d87b2> in plot_jaccard_distribution_multiple(ses)
#      25     sns.set_style({"xtick.direction": "in", "ytick.direction": "in"})
#      26     g = sns.factorplot(x="Jaccard Similarity Between Drug Target Profiles", y="Fraction of Drug Combinations", hue="", data=data,
# ---> 27                    size=18, kind="bar", palette=['#535456', '#9ea3a8', '#3478e5', '#e74c3c', '#2ecc71', '#cc6c18', '#9b59b6',], x_order=['No shared drug targets','Fewer than 50% shared','More than 50% shared'], hue_order=order)
#      28     plt.tight_layout()
#      29     plt.xlabel('')
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(*args, **kwargs)
#    3674     kwargs.setdefault("kind", "point")
#    3675
# -> 3676     return catplot(*args, **kwargs)
#    3677
#    3678
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3753
#    3754     # Draw the plot onto the facets
# -> 3755     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3756
#    3757     # Special case axis labels for a count type plot
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     818
#     819             # Draw the plot
# --> 820             self._facet_plot(func, ax, args, kwargs)
#     821
#     822         # Finalize the annotations and layout
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1644                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1645                         color=self.colors[j], align="center",
# -> 1646                         label=hue_level, **kws)
#    1647
#    1648                 # Draw the confidence intervals
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, *args, **kwargs)
#    2278                 label='_nolegend_',
#    2279                 )
# -> 2280             r.update(kwargs)
#    2281             r.get_path()._interpolation_steps = 100
#    2282             if orientation == 'vertical':
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/anaconda3/envs/lei_deepchem_env/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property x_order
